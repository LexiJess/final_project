# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("new_all_data2.csv")

# %%
df
# Out:
#        Country  2010_DR  2011_DR  2012_DR  2013_DR  2014_DR  2015_DR  2016_DR  \
# 0      Albania     54.0     53.5     53.0     52.6     52.1     51.6     51.1
# 1       Angola     99.7     99.3    102.0    105.0    108.0    111.0    114.0
# 2      Armenia     43.8     44.5     45.2     45.9     46.5     47.2     47.9
# 3   Azerbaijan     50.9     50.9     50.9     50.9     50.9     50.9     50.9
# 4   Bangladesh     68.5     67.8     66.3     64.9     63.4     61.8     60.2
# ..         ...      ...      ...      ...      ...      ...      ...      ...
# 67  Uzbekistan     51.0     49.3     47.6     46.0     44.3     42.7     41.0
# 68     Vietnam     48.9     48.8     48.8     48.7     48.6     48.5     48.5
# 69       Yemen     88.1     87.4     86.8     86.1     85.4     84.8     84.1
# 70      Zambia    109.0    109.0    109.0    109.0    109.0    108.0    106.0
# 71    Zimbabwe     89.3     88.3     88.8     89.3     89.7     90.2     90.0
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        Country  2010_DR  2011_DR  2012_DR  2013_DR  2014_DR  2015_DR  2016_DR  \
# 0      Albania     54.0     53.5     53.0     52.6     52.1     51.6     51.1
# 1       Angola     99.7     99.3    102.0    105.0    108.0    111.0    114.0
# 2      Armenia     43.8     44.5     45.2     45.9     46.5     47.2     47.9
# 3   Azerbaijan     50.9     50.9     50.9     50.9     50.9     50.9     50.9
# 4   Bangladesh     68.5     67.8     66.3     64.9     63.4     61.8     60.2
# ..         ...      ...      ...      ...      ...      ...      ...      ...
# 67  Uzbekistan     51.0     49.3     47.6     46.0     44.3     42.7     41.0
# 68     Vietnam     48.9     48.8     48.8     48.7     48.6     48.5     48.5
# 69       Yemen     88.1     87.4     86.8     86.1     85.4     84.8     84.1
# 70      Zambia    109.0    109.0    109.0    109.0    109.0    108.0    106.0
# 71    Zimbabwe     89.3     88.3     88.8     89.3     89.7     90.2     90.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Columns: 167 entries, Country to 2020_WAE
# dtypes: float64(165), object(2)
# memory usage: 94.1+ KB

# %%
df_gni = df[['GNI/C 2010','GNI/C 2011', 'GNI/C 2012', 'GNI/C 2013','GNI/C 2014','GNI/C 2015','GNI/C 2016','GNI/C 2017','GNI/C 2018','GNI/C 2019','GNI/C 2020']]
df_gni
# Out:
#     GNI/C 2010  GNI/C 2011  GNI/C 2012  GNI/C 2013  GNI/C 2014  GNI/C 2015  \
# 0         9.83       10.20       10.30       10.70       10.80       11.10
# 1         5.82        5.80        6.13        6.29        6.48        6.44
# 2         7.06        7.27        7.79        8.17        8.30        8.49
# 3        15.40       14.70       15.10       15.90       16.40       16.30
# 4         2.72        2.86        3.03        3.16        3.27        3.44
# ..         ...         ...         ...         ...         ...         ...
# 67        4.37        4.65        4.98        5.35        5.58        5.76
# 68        4.26        4.46        4.66        4.84        5.05        5.31
# 69        3.69        3.88        3.36        3.35        3.29        2.67
# 70        3.12        3.25        3.52        3.48        3.62        3.62
# 71        1.69        1.86        2.16        2.24        2.26        2.23
#
#     GNI/C 2016  GNI/C 2017  GNI/C 2018  GNI/C 2019  GNI/C 2020
# ...

# %%
df_gni.describe()
# Out:
#        GNI/C 2010  GNI/C 2011  GNI/C 2012  GNI/C 2013  GNI/C 2014  GNI/C 2015  \
# count   72.000000   72.000000   72.000000   72.000000   72.000000   72.000000
# mean     4.767361    4.888750    4.984722    5.200000    5.354861    5.510833
# std      4.227515    4.337382    4.465328    4.712557    4.861401    5.002379
# min      0.640000    0.650000    0.670000    0.670000    0.680000    0.710000
# 25%      1.772500    1.807500    1.717500    1.735000    1.802500    1.852500
# 50%      3.010000    3.150000    3.240000    3.270000    3.380000    3.530000
# 75%      6.412500    6.600000    6.467500    6.682500    6.865000    7.292500
# max     17.900000   19.500000   20.100000   21.400000   22.100000   23.200000
#
#        GNI/C 2016  GNI/C 2017  GNI/C 2018  GNI/C 2019  GNI/C 2020
# count   72.000000   72.000000   72.000000   72.000000   72.000000
# mean     5.524444    5.586667    5.668333    5.760278    5.852639
# std      4.943532    5.013390    5.052699    5.096278    5.143657
# ...

# %%
df_2020 = df[["GNI/C 2020", "2020_DR","2020_SC","2020_3BD","2020_HOS","LifeEx 2020", "2020_pop","2020_urb",
             "2020_WLE", "2020_WUE", "2020_MYE", "2020_MAE", "2020_MLE", "2020_MAE", "2020_WAE"]]
df_2020.head()
# Out:
#    GNI/C 2020  2020_DR  2020_SC  2020_3BD  2020_HOS  LifeEx 2020  2020_pop  \
# 0       13.20     49.1    10.40      19.0      3.88         78.7      2.85
# 1        5.31    125.0    37.20      29.9      6.47         61.6     32.50
# 2        9.70     50.6     8.15      28.5      4.53         75.2      2.98
# 3       15.10     50.9    26.40      13.8      5.02         73.2      8.49
# 4        4.58     53.7    27.10      27.6      4.91         72.9    165.00
#
#    2020_urb  2020_WLE  2020_WUE  2020_MYE  2020_MAE  2020_MLE  2020_MAE  \
# 0      65.0      55.5     22.60     12.50      21.6      69.6      21.6
# 1      70.9      46.4      7.26      5.63      34.5      45.5      34.5
# 2      57.0      38.1     36.40     11.60      13.7      64.8      13.7
# 3      55.2      33.1     49.00     10.60      13.1      66.5      13.1
# 4      20.7      35.0      5.14      5.83      24.0      72.2      24.0
#
#    2020_WAE
# 0      22.0
# 1      46.3
# 2      25.5
# 3      17.9
# 4     117.0

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   GNI/C 2020   72 non-null     float64
#  1   2020_DR      72 non-null     float64
#  2   2020_SC      72 non-null     float64
#  3   2020_3BD     72 non-null     float64
#  4   2020_HOS     72 non-null     float64
#  5   LifeEx 2020  72 non-null     float64
#  6   2020_pop     72 non-null     float64
#  7   2020_urb     72 non-null     float64
#  8   2020_WLE     68 non-null     float64
#  9   2020_WUE     68 non-null     float64
#  10  2020_MYE     72 non-null     float64
#  11  2020_MAE     69 non-null     float64
#  12  2020_MLE     69 non-null     float64
#  13  2020_MAE     69 non-null     float64
#  14  2020_WAE     68 non-null     float64
# dtypes: float64(15)
# memory usage: 8.6 KB

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
plt.figure(figsize=(16, 10))
sns.heatmap(df_2020.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %%
sns.scatterplot(data = df_2020, x="LifeEx 2020", y="GNI/C 2020")
# Out:
# <AxesSubplot:xlabel='LifeEx 2020', ylabel='GNI/C 2020'>

# %%
sns.scatterplot(data = df_2020, x="2020_3BD", y="GNI/C 2020")
# Out:
# <AxesSubplot:xlabel='2020_3BD', ylabel='GNI/C 2020'>

# %%
X = df_2020['LifeEx 2020']
y = df_2020['GNI/C 2020']

# %%
pip install -U scikit-learn
# Out:
# ...
#      |████████████████████████████████| 7.2 MB 7.0 MB/s eta 0:00:01
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.23.2
#     Uninstalling scikit-learn-0.23.2:
#       Successfully uninstalled scikit-learn-0.23.2
# ...
# WARNING: You are using pip version 20.3; however, version 21.0.1 is available.
# You should consider upgrading via the '/Users/daltonfield/opt/anaconda3/envs/PythonData/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, 
                                                    test_size = 0.3, random_state = 100)

# %%
X_train
# Out:
# 18    58.2
# 12    53.9
# 6     71.8
# 46    61.9
# 37    55.2
# 59    55.1
# 50    74.7
# 17    61.1
# 38    64.6
# 60    64.5
# 42    59.8
# 45    76.9
# 30    64.4
# 66    63.9
# 56    69.4
# 40    64.8
# 64    61.3
# 47    67.5
# 7     76.1
# 3     73.2
# 51    62.9
# 62    66.1
# 58    68.2
# 19    74.3
# 13    54.5
# 1     61.6
# 31    75.5
# 4     72.9
# 44    72.0
# 27    74.6
# 2     75.2
# 22    61.6
# 29    70.1
# 9     61.9
# 16    65.0
# 43    65.2
# 36    71.6
# 15    64.5
# 70    64.4
# 68    75.5
# 49    71.1
# 34    74.3
# 14    77.5
# 53    67.4
# 52    55.1
# 10    70.1
# 48    64.1
# 67    71.9
# 24    66.9
# 8     62.0
# Name: LifeEx 2020, dtype: float64

# %%
y_train
# Out:
# 18     3.92
# 12     0.82
# 6      7.27
# 46     1.18
# 37     3.28
# 59     1.42
# 50     4.58
# 17     0.83
# 38     1.00
# 60    11.50
# 42     1.97
# 45     7.76
# 30     1.67
# 66     1.81
# 56     2.18
# 40     1.18
# 64     1.65
# 47     6.40
# 7     14.30
# 3     15.10
# 51     0.93
# 62     2.93
# 58     3.49
# 19    16.80
# 13     1.68
# 1      5.31
# 31     4.49
# 4      4.58
# 44     7.31
# 27     7.57
# 2      9.70
# 22     9.28
# 29     7.96
# 9      0.64
# 16     5.55
# 43     3.87
# 36     3.55
# 15     2.32
# 70     3.64
# 68     6.84
# 49     2.97
# 34    22.40
# 14    12.80
# 53     5.51
# 52     4.86
# 10     3.96
# 48     9.49
# 67     7.01
# 24    15.10
# 8      1.84
# Name: GNI/C 2020, dtype: float64

# %%
# !pip install statsmodels
import statsmodels.api as sm
# Out:
# ...
#      |████████████████████████████████| 9.5 MB 3.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 231 kB 12.3 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 20.3; however, version 21.0.1 is available.
# You should consider upgrading via the '/Users/daltonfield/opt/anaconda3/envs/PythonData/bin/python -m pip install --upgrade pip' command.

# %%
X_train_sm = sm.add_constant(X_train)

# %%
lr = sm.OLS(y_train, X_train_sm).fit()

# %%
lr.params
# Out:
# const         -21.802680
# LifeEx 2020     0.411934
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             GNI/C 2020   R-squared:                       0.311
# Model:                            OLS   Adj. R-squared:                  0.296
# Method:                 Least Squares   F-statistic:                     21.63
# Date:                Thu, 11 Mar 2021   Prob (F-statistic):           2.62e-05
# Time:                        23:31:34   Log-Likelihood:                -139.91
# No. Observations:                  50   AIC:                             283.8
# Df Residuals:                      48   BIC:                             287.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         -21.8027      5.938     -3.671      0.001     -33.743      -9.863
# ...

# %%
#Since P is less that the 0.05, it is statistically significant
plt.scatter(X_train, y_train)
plt.plot(X_train, -21.8027 + 0.4119*X_train, 'r')
plt.show()

# %%
#Predicting the model and creating residuals
y_train_pred = lr.predict(X_train_sm)
res = (y_train - y_train_pred)

# %%
fig = plt.figure()
sns.distplot(res, bins = 15)
plt.title('Error Terms', fontsize = 15)
plt.xlabel('y_train - y_train_pred', fontsize = 15)
plt.show()

# %%
plt.scatter(X_train,res)
plt.show()

# %%
X_test_sm = sm.add_constant(X_test)
y_test_pred = lr.predict(X_test_sm)
y_test_pred
# Out:
# 55     9.916206
# 11     2.789755
# 32     6.991477
# 26     4.725842
# 28     3.778395
# 21     5.673290
# 61     7.568184
# 23     5.796870
# 41    10.822460
# 65    10.328139
# 20     7.938924
# 57     7.279831
# 5      3.778395
# 39     5.961643
# 63     6.950284
# 33     8.927565
# 25     3.860782
# 71     3.737202
# 54     4.890616
# 69     5.426130
# 35     5.879257
# 0     10.616493
# dtype: float64

# %%
from sklearn.metrics import r2_score
r_squared = r2_score(y_test, y_test_pred)
r_squared
# Out:
# 0.48526215658276384

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, y_test_pred, 'r')
plt.show()
