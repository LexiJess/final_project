# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
import os
style.use("ggplot")
# Set the seed value for the notebook so the results are reproducible
from numpy.random import seed
seed(1)

# linear regression feature importance
from sklearn.datasets import make_regression
from sklearn.linear_model import LogisticRegression
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
import sklearn
import sklearn.datasets

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
df_training = pd.read_csv("df_training.csv")
df_training
# Out:
#      GNI     DR    SC   3BD   HOS  LifeEx     pop   urb   WLE    WUE    MYE  \
# 0     10   54.0  21.4  23.2  4.58    76.6    2.92  46.7  55.5  22.60   9.45
# 1      6   99.7  37.2  22.9  6.30    55.4   23.50  43.7  46.4   7.26   5.57
# 2      7   43.8  20.6  28.5  4.55    73.3    2.88  61.9  39.2  46.70  11.40
# 3     15   50.9  26.4  13.8  5.02    70.9    8.49  55.2  33.1  49.00  10.60
# 4      3   68.5  42.5  27.1  6.09    69.9  148.00  23.9  77.5  12.20   4.44
# ..   ...    ...   ...   ...   ...     ...     ...   ...   ...    ...    ...
# 675    2  106.0  25.4  27.6  6.06    63.4   43.40  26.3  47.6  10.90   6.86
# 676    7   48.2  22.7  23.9  4.82    75.4   96.40  34.6  37.8  12.80   8.50
# 677    1   82.1  46.3  25.2  7.96    66.1   29.00  30.9  33.2  21.80   5.36
# 678    4  100.0  33.4  27.5  6.47    64.0   17.80  40.0  55.6   8.25   7.50
# 679    3   89.3  23.5  22.6  5.18    61.6   14.70  31.5  73.8  16.50   8.96
#
#        MAE   MLE    MUE   WAE
# 0    21.60  69.6   8.83  22.0
# 1    34.50  45.5  19.90  46.3
# 2     9.63  72.4  18.00  14.1
# 3    13.10  66.5  20.40  17.9
# 4    29.40  58.3  12.20  10.3
# ..     ...   ...    ...   ...
# 675  31.30  61.1  19.00  42.6
# 676  39.20  54.3   6.46  49.4
# 677  19.10  67.2  13.60  45.1
# 678  36.70  55.0   9.64  37.0
# 679  11.80  73.2  18.20  12.3
#
# [680 rows x 15 columns]

# %%
target = df_training["GNI"]
# target_names = ["negative", "positive"]
decimals=0
df_training['GNI'] = df_training['GNI'].apply(lambda x: round(x, decimals))

df_training

# #What's our target?
# target_df=pd.DataFrame(target)


# # target_df.round(0)

# target_df=target_df.round(decimals=0)
# target_df
# Out:
#      GNI     DR    SC   3BD   HOS  LifeEx     pop   urb   WLE    WUE    MYE  \
# 0     10   54.0  21.4  23.2  4.58    76.6    2.92  46.7  55.5  22.60   9.45
# 1      6   99.7  37.2  22.9  6.30    55.4   23.50  43.7  46.4   7.26   5.57
# 2      7   43.8  20.6  28.5  4.55    73.3    2.88  61.9  39.2  46.70  11.40
# 3     15   50.9  26.4  13.8  5.02    70.9    8.49  55.2  33.1  49.00  10.60
# 4      3   68.5  42.5  27.1  6.09    69.9  148.00  23.9  77.5  12.20   4.44
# ..   ...    ...   ...   ...   ...     ...     ...   ...   ...    ...    ...
# 675    2  106.0  25.4  27.6  6.06    63.4   43.40  26.3  47.6  10.90   6.86
# 676    7   48.2  22.7  23.9  4.82    75.4   96.40  34.6  37.8  12.80   8.50
# 677    1   82.1  46.3  25.2  7.96    66.1   29.00  30.9  33.2  21.80   5.36
# 678    4  100.0  33.4  27.5  6.47    64.0   17.80  40.0  55.6   8.25   7.50
# 679    3   89.3  23.5  22.6  5.18    61.6   14.70  31.5  73.8  16.50   8.96
#
#        MAE   MLE    MUE   WAE
# 0    21.60  69.6   8.83  22.0
# 1    34.50  45.5  19.90  46.3
# 2     9.63  72.4  18.00  14.1
# 3    13.10  66.5  20.40  17.9
# 4    29.40  58.3  12.20  10.3
# ..     ...   ...    ...   ...
# 675  31.30  61.1  19.00  42.6
# 676  39.20  54.3   6.46  49.4
# 677  19.10  67.2  13.60  45.1
# 678  36.70  55.0   9.64  37.0
# 679  11.80  73.2  18.20  12.3
#
# [680 rows x 15 columns]

# %%
data = df_training
data = df_training.drop("GNI", axis=1)
feature_names = data.columns
data.head()
# Out:
#      DR    SC   3BD   HOS  LifeEx     pop   urb   WLE    WUE    MYE    MAE  \
# 0  54.0  21.4  23.2  4.58    76.6    2.92  46.7  55.5  22.60   9.45  21.60
# 1  99.7  37.2  22.9  6.30    55.4   23.50  43.7  46.4   7.26   5.57  34.50
# 2  43.8  20.6  28.5  4.55    73.3    2.88  61.9  39.2  46.70  11.40   9.63
# 3  50.9  26.4  13.8  5.02    70.9    8.49  55.2  33.1  49.00  10.60  13.10
# 4  68.5  42.5  27.1  6.09    69.9  148.00  23.9  77.5  12.20   4.44  29.40
#
#     MLE    MUE   WAE
# 0  69.6   8.83  22.0
# 1  45.5  19.90  46.3
# 2  72.4  18.00  14.1
# 3  66.5  20.40  17.9
# 4  58.3  12.20  10.3

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

y_train
target
# Out:
# 0      10
# 1       6
# 2       7
# 3      15
# 4       3
#        ..
# 675     2
# 676     7
# 677     1
# 678     4
# 679     3
# Name: GNI, Length: 680, dtype: int64

# %%
# Support vector machine linear classifier
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
# Model Accuracy
print('Test Acc: %.3f' % model.score(X_test, y_test))
# Out:
# Test Acc: 0.641

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV

param_grid = {'C': [1, 5, 10],
              'gamma': [0.0001, 0.001, 0.01]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] C=1, gamma=0.0001 ...............................................
# C:\Users\hanso\Anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................... C=1, gamma=0.0001, score=0.657, total=   0.8s
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [CV] ................... C=1, gamma=0.0001, score=0.716, total=   1.8s
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.5s remaining:    0.0s
# [CV] ................... C=1, gamma=0.0001, score=0.667, total=   0.7s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.667, total=   1.2s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.578, total=   1.2s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.657, total=   0.8s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.716, total=   1.7s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.667, total=   0.9s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.667, total=   1.2s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.578, total=   1.3s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.657, total=   0.9s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.716, total=   1.7s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.667, total=   0.7s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.667, total=   1.1s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.578, total=   1.2s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.647, total=   3.6s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.745, total=   4.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.667, total=   2.9s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.637, total=   5.0s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.637, total=   3.7s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.647, total=   3.7s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.745, total=   3.7s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.667, total=   2.7s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.637, total=   5.7s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.637, total=   4.1s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ..................... C=5, gamma=0.01, score=0.647, total=   3.6s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ..................... C=5, gamma=0.01, score=0.745, total=   3.9s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ..................... C=5, gamma=0.01, score=0.667, total=   2.7s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ..................... C=5, gamma=0.01, score=0.637, total=   5.1s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ..................... C=5, gamma=0.01, score=0.637, total=   4.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.637, total=   6.2s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.745, total=   7.4s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.667, total=   5.6s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.657, total=  11.5s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.618, total=   7.3s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.637, total=   6.3s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.745, total=   7.1s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.667, total=   6.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.657, total=  11.8s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.618, total=   7.6s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.637, total=   6.1s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.745, total=   7.2s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.667, total=   5.8s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.657, total=  11.7s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.618, total=   7.1s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:  3.2min finished
# GridSearchCV(estimator=SVC(kernel='linear'),
#              param_grid={'C': [1, 5, 10], 'gamma': [0.0001, 0.001, 0.01]},
#              verbose=3)

# %%
# Calculate classification report
from sklearn.metrics import classification_report
predictions = model.predict(X_test)
print(classification_report(y_test, predictions,
                            target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.72      0.76      0.74        17
#            2       0.64      0.81      0.71        31
#            3       0.68      0.54      0.60        39
#            4       0.50      0.44      0.47        16
#            5       0.56      0.82      0.67        11
#            6       0.44      0.44      0.44         9
#            7       0.67      0.55      0.60        11
#            8       1.00      0.50      0.67         8
#            9       0.67      1.00      0.80         4
#           10       0.83      0.83      0.83         6
#           11       1.00      0.75      0.86         4
#           12       1.00      1.00      1.00         4
#           13       1.00      0.75      0.86         4
#           14       0.00      0.00      0.00         0
#           15       0.00      0.00      0.00         1
#           16       0.50      0.25      0.33         4
#           17       0.00      0.00      0.00         0
#           22       0.00      0.00      0.00         0
#           23       0.00      0.00      0.00         1
#
#     accuracy                           0.64       170
#    macro avg       0.54      0.50      0.50       170
# weighted avg       0.67      0.64      0.64       170
# C:\Users\hanso\Anaconda3\envs\PythonData\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\hanso\Anaconda3\envs\PythonData\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(grid.best_params_)
# Out:
# {'C': 5, 'gamma': 0.0001}

# %%
predictions = grid.predict(X_test)
predictions
# Out:
# array([ 5,  2,  1,  3,  3,  4,  3,  4,  3,  4,  2,  3,  5,  2,  1, 15,  2,
#         2,  6,  9,  7,  4,  2,  4,  2,  1,  3,  2, 10,  2, 10, 10,  3,  1,
#         7,  2,  3, 14,  2,  2,  3,  3,  3,  1,  2,  6,  6,  5,  9,  3,  4,
#         1, 14,  1, 12,  2,  5,  3,  2, 16,  3,  2,  3,  6,  4,  5,  7,  5,
#         2,  3,  5,  2,  2, 17,  1,  9,  5,  6,  8,  1,  1,  9,  2, 11,  2,
#         6,  3,  1,  3,  2,  1,  1,  2,  3, 16, 11,  3,  3,  5,  4,  3, 13,
#        10,  2, 12,  2,  3, 10,  5,  3, 10,  2,  4,  5,  2,  3,  2,  7,  3,
#         2,  7,  2,  7,  1,  3,  3,  4, 22, 12,  4,  3,  7,  5,  5,  9,  7,
#         3,  2,  8, 10,  9,  2,  4,  1,  2,  1,  4,  3, 17,  1,  2, 13,  2,
#         1, 13,  8,  2,  7,  4, 11,  2,  3,  7,  3,  3,  5,  2,  3,  1, 12],
#       dtype=int64)
